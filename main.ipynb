# %%
from resnet_transfer_learning import ResNetExtension

# %%
res_ext = ResNetExtension(images_path='/home/std/Downloads/images/')

# %%
res_ext.load_images()
# Out:
# Found 20050 files belonging to 2 classes.
# Found 4950 files belonging to 2 classes.

# %%
res_ext.build_model()

# %%
res_ext.compile_model()

# %%
res_ext.fit_model()
# Out:
# Epoch 1/10
# 10/10 [==============================] - 21s 2s/step - loss: 1.8326 - accuracy: 0.6187 - val_loss: 0.8014 - val_accuracy: 0.8125
# Epoch 2/10
# 10/10 [==============================] - 18s 2s/step - loss: 0.7359 - accuracy: 0.8500 - val_loss: 0.3717 - val_accuracy: 0.8969
# Epoch 3/10
# 10/10 [==============================] - 18s 2s/step - loss: 0.3333 - accuracy: 0.9187 - val_loss: 0.3063 - val_accuracy: 0.9312
# Epoch 4/10
# 10/10 [==============================] - 18s 2s/step - loss: 0.3315 - accuracy: 0.9250 - val_loss: 0.3485 - val_accuracy: 0.9344
# Epoch 5/10
# 10/10 [==============================] - 18s 2s/step - loss: 0.3524 - accuracy: 0.9125 - val_loss: 0.1979 - val_accuracy: 0.9438
# Epoch 6/10
# 10/10 [==============================] - 17s 2s/step - loss: 0.2119 - accuracy: 0.9312 - val_loss: 0.2350 - val_accuracy: 0.9406
# Epoch 7/10
# ...

# %%
res_ext.predict_image('/home/std/Downloads/images/extra/1.jpg')
# Out:
# 'dog'

# %%
res_ext.predict_image('/home/std/Downloads/images/extra/2.jpg')
# Out:
# 'dog'

# %%
res_ext.predict_image('/home/std/Downloads/images/extra/3.jpg')
# Out:
# 'dog'

# %%
res_ext.predict_image('/home/std/Downloads/images/extra/4.jpg')
# Out:
# 'dog'

# %%
res_ext.predict_image('/home/std/Downloads/images/extra/5.jpg')
# Out:
# 'cat'

# %%
res_ext.predict_image('/home/std/Downloads/images/extra/6.jpg')
# Out:
# 'cat'
